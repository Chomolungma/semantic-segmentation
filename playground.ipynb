# %%
import tensorflow as tf
import os.path
import warnings
from distutils.version import LooseVersion
import glob

import helper
import project_tests as tests

# %%
# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.0'), 'Please use TensorFlow version 1.0 or newer.  You are using {}'.format(tf.__version__)
print('TensorFlow Version: {}'.format(tf.__version__))
# Out:
# TensorFlow Version: 1.2.1

# %%
# Check for a GPU
if not tf.test.gpu_device_name():
  warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
  print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# Default GPU Device: /gpu:0

# %%
DATA_DIRECTORY = './data'
RUNS_DIRECTORY = './runs'
SAVED_MODEL_DIRECTORY = './data/fcn'
TRAINING_DATA_DIRECTORY ='./data/data_road/training'
NUMBER_OF_IMAGES = len(glob.glob('./data/data_road/training/calib/*.*'))
VGG_PATH = './data/vgg'

# %%
NUMBER_OF_CLASSES = 2
IMAGE_SHAPE = (160, 576)

EPOCHS = 20
BATCH_SIZE = 1

LEARNING_RATE = 0.0001
DROPOUT = 0.75

# %%
correct_label = tf.placeholder(tf.float32, [None, IMAGE_SHAPE[0], IMAGE_SHAPE[1], NUMBER_OF_CLASSES])
learning_rate = tf.placeholder(tf.float32)
keep_prob = tf.placeholder(tf.float32)

# %%
all_training_losses = [] # Used for plotting to visualize if our training is going well given parameters

# %%
def load_vgg(sess, vgg_path):
  """
  Load Pretrained VGG Model into TensorFlow.
  sess: TensorFlow Session
  vgg_path: Path to vgg folder, containing "variables/" and "saved_model.pb"
  return: Tuple of Tensors from VGG model (image_input, keep_prob, layer3, layer4, layer7)
  """
  # load the model and weights
  model = tf.saved_model.loader.load(sess, ['vgg16'], vgg_path)

  # Get Tensors to be returned from graph
  graph = tf.get_default_graph()
  image_input = graph.get_tensor_by_name('image_input:0')
  keep_prob = graph.get_tensor_by_name('keep_prob:0')
  layer3 = graph.get_tensor_by_name('layer3_out:0')
  layer4 = graph.get_tensor_by_name('layer4_out:0')
  layer7 = graph.get_tensor_by_name('layer7_out:0')

  return image_input, keep_prob, layer3, layer4, layer7

# %%
def conv_1x1(layer, layer_name):
  """ Return the output of a 1x1 convolution of a layer """
  return tf.layers.conv2d(inputs = layer,
                          filters =  NUMBER_OF_CLASSES,
                          kernel_size = (1, 1),
                          strides = (1, 1),
                          name = layer_name)

# %%
def upsample(layer, k, s, layer_name):
  """ Return the output of transpose convolution given kernel_size k and strides s """
  # See: http://deeplearning.net/software/theano/tutorial/conv_arithmetic.html#transposed-convolution-arithmetic
  return tf.layers.conv2d_transpose(inputs = layer,
                                    filters = NUMBER_OF_CLASSES,
                                    kernel_size = (k, k),
                                    strides = (s, s),
                                    padding = 'same',
                                    name = layer_name)

# %%
def layers(vgg_layer3_out, vgg_layer4_out, vgg_layer7_out, num_classes = NUMBER_OF_CLASSES):
  """
  Create the layers for a fully convolutional network.  Build skip-layers using the vgg layers.
  vgg_layerX_out: TF Tensor for VGG Layer X output
  num_classes: Number of classes to classify
  return: The Tensor for the last layer of output
  """

  # Use a shorter variable name for simplicity
  layer3, layer4, layer7 = vgg_layer3_out, vgg_layer4_out, vgg_layer7_out

  # Apply a 1x1 convolution to encoder layers
  layer3x = conv_1x1(layer = layer3, layer_name = "layer3conv1x1")
  layer4x = conv_1x1(layer = layer4, layer_name = "layer4conv1x1")
  layer7x = conv_1x1(layer = layer7, layer_name = "layer7conv1x1")
 
  # Add decoder layers to the network with skip connections and upsampling
  # Note: the kernel size and strides are the same as the example in Udacity Lectures
  #       Semantic Segmentation Scene Understanding Lesson 10-9: FCN-8 - Decoder
  decoderlayer1 = upsample(layer = layer7x, k = 4, s = 2, layer_name = "decoderlayer1")
  decoderlayer2 = tf.add(decoderlayer1, layer4x, name = "decoderlayer2")
  decoderlayer3 = upsample(layer = decoderlayer2, k = 4, s = 2, layer_name = "decoderlayer3")
  decoderlayer4 = tf.add(decoderlayer3, layer3x, name = "decoderlayer4")
  decoderlayer_output = upsample(layer = decoderlayer4, k = 16, s = 8, layer_name = "decoderlayer_output")

  return decoderlayer_output

# %%
def layers_verbose(vgg_layer3_out, vgg_layer4_out, vgg_layer7_out, num_classes = NUMBER_OF_CLASSES):

  # Use a shorter variable name for simplicity
  layer3, layer4, layer7 = vgg_layer3_out, vgg_layer4_out, vgg_layer7_out

  # Apply a 1x1 convolution to encoder layers
  layer3x = conv_1x1(layer = layer3, layer_name = "layer3conv1x1")
  layer4x = conv_1x1(layer = layer4, layer_name = "layer4conv1x1")
  layer7x = conv_1x1(layer = layer7, layer_name = "layer7conv1x1")
 
  decoderlayer1 = upsample(layer = layer7x, k = 4, s = 2, layer_name = "decoderlayer1")
  decoderlayer2 = tf.add(decoderlayer1, layer4x, name = "decoderlayer2")
  decoderlayer3 = upsample(layer = decoderlayer2, k = 4, s = 2, layer_name = "decoderlayer3")
  decoderlayer4 = tf.add(decoderlayer3, layer3x, name = "decoderlayer4")
  decoderlayer_output = upsample(layer = decoderlayer4, k = 16, s = 8, layer_name = "decoderlayer_output")

  return layer3, layer4, layer7, layer3x, layer4x, layer7x, decoderlayer1, decoderlayer2, decoderlayer3, decoderlayer4, decoderlayer_output

# %%
def optimize(nn_last_layer, correct_label, learning_rate, num_classes = NUMBER_OF_CLASSES):
  """
  Build the TensorFLow loss and optimizer operations.
  nn_last_layer: TF Tensor of the last layer in the neural network
  correct_label: TF Placeholder for the correct label image
  learning_rate: TF Placeholder for the learning rate
  num_classes: Number of classes to classify
  return: Tuple of (logits, train_op, cross_entropy_loss)
  """
  # reshape 4D tensors to 2D
  # Each row represents a pixel, each column a class
  logits = tf.reshape(nn_last_layer, (-1, num_classes))
  class_labels = tf.reshape(correct_label, (-1, num_classes))

  # The cross_entropy_loss is the cost which we are trying to minimize to yield higher accuracy
  cross_entropy = tf.nn.softmax_cross_entropy_with_logits(logits = logits, labels = class_labels)
  cross_entropy_loss = tf.reduce_mean(cross_entropy)

  # The model implements this operation to find the weights/parameters that would yield correct pixel labels
  train_op = tf.train.AdamOptimizer(learning_rate).minimize(cross_entropy_loss)

  return logits, train_op, cross_entropy_loss

# %%
def train_nn(sess, epochs, batch_size, get_batches_fn, train_op,
             cross_entropy_loss, input_image,
             correct_label, keep_prob, learning_rate):
  """
  Train neural network and print out the loss during training.
  sess: TF Session
  epochs: Number of epochs
  batch_size: Batch size
  get_batches_fn: Function to get batches of training data.  Call using get_batches_fn(batch_size)
  train_op: TF Operation to train the neural network
  cross_entropy_loss: TF Tensor for the amount of loss
  input_image: TF Placeholder for input images
  correct_label: TF Placeholder for label images
  keep_prob: TF Placeholder for dropout keep probability
  learning_rate: TF Placeholder for learning rate
  """
    
  saver = tf.train.Saver()
  tf.add_to_collection('train_op', train_op)    
  tf.add_to_collection('cross_entropy_loss', cross_entropy_loss)    

  for epoch in range(EPOCHS):
    
    losses, i = [], 0
    
    for images, labels in get_batches_fn(BATCH_SIZE):
        
      i += 1
    
      feed = { input_image: images,
               correct_label: labels,
               keep_prob: DROPOUT,
               learning_rate: LEARNING_RATE }
        
      _, partial_loss = sess.run([train_op, cross_entropy_loss], feed_dict = feed)
      
      print("---> iteration: ", i, " partial loss:", partial_loss)
      losses.append(partial_loss)
        
      if i % 100 == 0:
        print("save model")
        saver.save(sess, 'model', global_step = 100)
          
    training_loss = sum(losses) / len(losses)
    all_training_losses.append(training_loss)
    
    print("------------------")
    print("epoch: ", epoch + 1, " of ", EPOCHS, "training loss: ", training_loss)
    print("------------------")

# %%
def run_tests():
  tests.test_layers(layers)
  tests.test_optimize(optimize)
  tests.test_for_kitti_dataset(DATA_DIRECTORY)
  tests.test_train_nn(train_nn)

# %%
def run():
  print("NUMBER OF IMAGES:", NUMBER_OF_IMAGES)

  # download vgg model
  helper.maybe_download_pretrained_vgg(DATA_DIRECTORY)

  # A function to get batches
  get_batches_fn = helper.gen_batch_function(TRAINING_DATA_DIRECTORY, IMAGE_SHAPE)
  
  with tf.Session() as session:
    
    try:
      new_saver = tf.train.import_meta_graph('model-100.meta')
      new_saver.restore(sess, 'model-100')
    except:
      print("model doesn't exist.")
    
    # Returns the three layers, keep probability and input layer from the vgg architecture
    image_input, keep_prob, layer3, layer4, layer7 = load_vgg(session, VGG_PATH)

    # The resulting network architecture, adding a decoder on top of the given vgg model
    model_output = layers(layer3, layer4, layer7, NUMBER_OF_CLASSES)

    # Returns the output logits, training operation and cost operation to be used
    # For the logits: each row represents a pixel, each column a class
    # training operation is what is used to get the right parameters to the model to correctly label the pixels
    # the cross entropy loss is the cost which we are minimizing, lower cost should yield higher accuracy
    logits, train_op, cross_entropy_loss = optimize(model_output, correct_label, learning_rate, NUMBER_OF_CLASSES)
    
    # Initilize all variables
    session.run([tf.global_variables_initializer(), tf.local_variables_initializer()])

    # train the neural network
    train_nn(session, EPOCHS, BATCH_SIZE, get_batches_fn, 
             train_op, cross_entropy_loss, image_input,
             correct_label, keep_prob, learning_rate)

    # Save inference data
    helper.save_inference_samples(RUNS_DIRECTORY, DATA_DIRECTORY, session, IMAGE_SHAPE, logits, keep_prob, image_input)

# %%
import numpy as np 

def network_shapes():
  with tf.Session() as sess:
    
    x = np.random.randn(1, 160, 576, 3)
    
    image_input, keep_prob, layer3, layer4, layer7 = load_vgg(sess, VGG_PATH)
 
    op = layers_verbose(layer3, layer4, layer7, NUMBER_OF_CLASSES)
  
    sess.run([tf.global_variables_initializer(), tf.local_variables_initializer()])

    l3, l4, l7, l3x, l4x, l7x, d1, s2, d3, s4, d5 = sess.run(op, feed_dict = {image_input: x, keep_prob: 1.0})

    print("------------------")
    print("shapes of layers:") 
    print("------------------")

    print("layer3 -->", l3.shape)
    print("layer4 -->", l4.shape)
    print("layer7 -->", l7.shape)
    print("layer3 conv1x1 -->", l3x.shape)
    print("layer4 conv1x1 -->", l4x.shape)
    print("layer7 conv1x1-->", l7x.shape)
    print("decoderlayer1 transpose: layer7 k = 4 s = 2 -->", d1.shape)
    print("decoderlayer2 skip: decoderlayer1 and layer4conv1x1 -->", s2.shape)
    print("decoderlayer3 transpose: decoderlayer2 k = 4 s = 2 -->", d3.shape)
    print("decoderlayer4 skip: decoderlayer3 and layer3conv1x1 -->", s4.shape)
    print("decoderlayer5 transpose: decoderlayer4 k = 16 s = 8 -->", d5.shape)

# %% [markdown]
# # `network_shape()`
# - for the transpose layers **`s = stride`** and **`k = kernel/filter_size`**
# - running **`network_shape()`** will output the following:
#
#
# ```
# ------------------
# shapes of layers:
# ------------------
# layer3 --> (1, 20, 72, 256)
# layer4 --> (1, 10, 36, 512)
# layer7 --> (1, 5, 18, 4096)
# layer3 conv1x1 --> (1, 20, 72, 2)
# layer4 conv1x1 --> (1, 10, 36, 2)
# layer7 conv1x1--> (1, 5, 18, 2)
# decoderlayer1 transpose: layer7 k = 4 s = 2 --> (1, 10, 36, 2)
# decoderlayer2 skip: decoderlayer1 and layer4conv1x1 --> (1, 10, 36, 2)
# decoderlayer3 transpose: decoderlayer2 k = 4 s = 2 --> (1, 20, 72, 2)
# decoderlayer4 skip: decoderlayer3 and layer3conv1x1 --> (1, 20, 72, 2)
# decoderlayer5 transpose: decoderlayer4 k = 16 s = 8 --> (1, 160, 576, 2)
# ```

# %%
# Train the network
run()
# Out:
# NUMBER OF IMAGES: 289
# model doesn't exist.
# INFO:tensorflow:Restoring parameters from b'./data/vgg/variables/variables'
# ---> iteration:  1  partial loss: 48.5083
# ---> iteration:  2  partial loss: 45.7682
# ---> iteration:  3  partial loss: 47.3777
# ---> iteration:  4  partial loss: 30.6055
# ---> iteration:  5  partial loss: 18.9753
# ---> iteration:  6  partial loss: 20.9578
# ---> iteration:  7  partial loss: 24.7754
# ---> iteration:  8  partial loss: 19.3241
# ---> iteration:  9  partial loss: 16.1408
# ---> iteration:  10  partial loss: 13.2739
# ---> iteration:  11  partial loss: 11.535
# ---> iteration:  12  partial loss: 11.2304
# ---> iteration:  13  partial loss: 8.98054
# ---> iteration:  14  partial loss: 9.71214
# ---> iteration:  15  partial loss: 8.68705
# ---> iteration:  16  partial loss: 8.30066
# ---> iteration:  17  partial loss: 7.60132
# ---> iteration:  18  partial loss: 7.84413
# ---> iteration:  19  partial loss: 6.38062
# ---> iteration:  20  partial loss: 6.52798
# ---> iteration:  21  partial loss: 4.69283
# ---> iteration:  22  partial loss: 5.09785
# ---> iteration:  23  partial loss: 5.05005
# ---> iteration:  24  partial loss: 3.98917
# ---> iteration:  25  partial loss: 3.99449
# ---> iteration:  26  partial loss: 3.54
# ---> iteration:  27  partial loss: 3.74598
# ---> iteration:  28  partial loss: 3.93982
# ---> iteration:  29  partial loss: 3.15842
# ---> iteration:  30  partial loss: 3.25174
# ---> iteration:  31  partial loss: 2.82869
# ---> iteration:  32  partial loss: 3.5147
# ---> iteration:  33  partial loss: 2.61528
# ---> iteration:  34  partial loss: 3.09637
# ---> iteration:  35  partial loss: 2.96329
# ---> iteration:  36  partial loss: 2.46073
# ---> iteration:  37  partial loss: 2.52196
# ---> iteration:  38  partial loss: 3.00901
# ---> iteration:  39  partial loss: 2.44294
# ---> iteration:  40  partial loss: 1.97023
# ---> iteration:  41  partial loss: 2.73219
# ---> iteration:  42  partial loss: 1.96775
# ---> iteration:  43  partial loss: 2.06643
# ---> iteration:  44  partial loss: 2.04576
# ---> iteration:  45  partial loss: 2.36638
# ---> iteration:  46  partial loss: 2.15705
# ---> iteration:  47  partial loss: 1.81917
# ---> iteration:  48  partial loss: 1.86219
# ---> iteration:  49  partial loss: 1.9468
# ---> iteration:  50  partial loss: 1.77955
# ---> iteration:  51  partial loss: 1.75729
# ---> iteration:  52  partial loss: 1.87722
# ---> iteration:  53  partial loss: 1.82793
# ---> iteration:  54  partial loss: 1.78728
# ---> iteration:  55  partial loss: 1.38229
# ---> iteration:  56  partial loss: 2.13406
# ---> iteration:  57  partial loss: 1.45271
# ---> iteration:  58  partial loss: 1.37843
# ---> iteration:  59  partial loss: 1.39968
# ---> iteration:  60  partial loss: 1.40916
# ---> iteration:  61  partial loss: 1.80514
# ---> iteration:  62  partial loss: 1.67463
# ---> iteration:  63  partial loss: 1.95371
# ---> iteration:  64  partial loss: 1.36656
# ---> iteration:  65  partial loss: 1.34944
# ---> iteration:  66  partial loss: 1.18629
# ---> iteration:  67  partial loss: 1.50382
# ---> iteration:  68  partial loss: 1.30784
# ---> iteration:  69  partial loss: 1.2491
# ---> iteration:  70  partial loss: 1.46887
# ---> iteration:  71  partial loss: 1.32701
# ---> iteration:  72  partial loss: 1.26323
# ---> iteration:  73  partial loss: 1.23758
# ---> iteration:  74  partial loss: 1.20668
# ---> iteration:  75  partial loss: 1.3299
# ---> iteration:  76  partial loss: 1.08528
# ---> iteration:  77  partial loss: 1.39562
# ---> iteration:  78  partial loss: 1.25538
# ---> iteration:  79  partial loss: 1.13969
# ---> iteration:  80  partial loss: 1.39772
# ---> iteration:  81  partial loss: 1.16234
# ---> iteration:  82  partial loss: 1.34565
# ---> iteration:  83  partial loss: 1.08827
# ---> iteration:  84  partial loss: 1.24365
# ---> iteration:  85  partial loss: 1.09789
# ---> iteration:  86  partial loss: 1.12793
# ---> iteration:  87  partial loss: 1.16868
# ---> iteration:  88  partial loss: 1.08719
# ---> iteration:  89  partial loss: 1.08223
# ---> iteration:  90  partial loss: 1.0469
# ---> iteration:  91  partial loss: 1.06781
# ---> iteration:  92  partial loss: 1.04754
# ---> iteration:  93  partial loss: 1.25869
# ---> iteration:  94  partial loss: 1.27661
# ---> iteration:  95  partial loss: 1.6614
# ---> iteration:  96  partial loss: 1.21329
# ---> iteration:  97  partial loss: 1.1123
# ---> iteration:  98  partial loss: 1.01887
# ---> iteration:  99  partial loss: 1.19788
# ---> iteration:  100  partial loss: 0.957963
# save model
# ---> iteration:  101  partial loss: 1.05048
# ---> iteration:  102  partial loss: 1.27167
# ---> iteration:  103  partial loss: 1.08855
# ---> iteration:  104  partial loss: 0.978853
# ---> iteration:  105  partial loss: 1.01712
# ---> iteration:  106  partial loss: 0.977575
# ---> iteration:  107  partial loss: 1.04317
# ---> iteration:  108  partial loss: 0.950485
# ---> iteration:  109  partial loss: 0.965044
# ---> iteration:  110  partial loss: 0.968922
# ---> iteration:  111  partial loss: 0.892724
# ---> iteration:  112  partial loss: 0.933797
# ---> iteration:  113  partial loss: 1.04485
# ---> iteration:  114  partial loss: 1.09425
# ---> iteration:  115  partial loss: 1.03415
# ---> iteration:  116  partial loss: 1.09809
# ---> iteration:  117  partial loss: 1.00854
# ---> iteration:  118  partial loss: 0.890236
# ---> iteration:  119  partial loss: 0.884431
# ---> iteration:  120  partial loss: 0.971119
# ---> iteration:  121  partial loss: 1.07147
# ---> iteration:  122  partial loss: 0.884887
# ---> iteration:  123  partial loss: 0.933452
# ---> iteration:  124  partial loss: 0.895149
# ---> iteration:  125  partial loss: 0.888416
# ---> iteration:  126  partial loss: 0.97075
# ---> iteration:  127  partial loss: 0.875238
# ---> iteration:  128  partial loss: 0.904575
# ---> iteration:  129  partial loss: 0.957585
# ---> iteration:  130  partial loss: 0.878085
# ---> iteration:  131  partial loss: 0.935184
# ---> iteration:  132  partial loss: 0.889848
# ---> iteration:  133  partial loss: 1.10837
# ---> iteration:  134  partial loss: 0.903701
# ---> iteration:  135  partial loss: 0.931129
# ---> iteration:  136  partial loss: 0.929057
# ---> iteration:  137  partial loss: 0.994649
# ---> iteration:  138  partial loss: 0.963102
# ---> iteration:  139  partial loss: 0.921941
# ---> iteration:  140  partial loss: 0.812366
# ---> iteration:  141  partial loss: 0.937642
# ---> iteration:  142  partial loss: 0.954383
# ---> iteration:  143  partial loss: 0.848468
# ---> iteration:  144  partial loss: 0.876326
# ---> iteration:  145  partial loss: 0.823804
# ---> iteration:  146  partial loss: 0.807244
# ---> iteration:  147  partial loss: 0.949273
# ---> iteration:  148  partial loss: 0.813864
# ---> iteration:  149  partial loss: 0.899943
# ---> iteration:  150  partial loss: 0.852289
# ---> iteration:  151  partial loss: 0.855027
# ---> iteration:  152  partial loss: 0.812022
# ---> iteration:  153  partial loss: 0.842388
# ---> iteration:  154  partial loss: 0.850764
# ---> iteration:  155  partial loss: 0.83573
# ---> iteration:  156  partial loss: 0.860006
# ---> iteration:  157  partial loss: 0.816118
# ---> iteration:  158  partial loss: 0.887457
# ---> iteration:  159  partial loss: 0.958148
# ---> iteration:  160  partial loss: 0.85837
# ---> iteration:  161  partial loss: 0.839036
# ---> iteration:  162  partial loss: 0.834348
# ---> iteration:  163  partial loss: 0.806899
# ---> iteration:  164  partial loss: 0.801432
# ---> iteration:  165  partial loss: 0.862719
# ---> iteration:  166  partial loss: 0.818864
# ---> iteration:  167  partial loss: 0.851935
# ---> iteration:  168  partial loss: 0.830412
# ---> iteration:  169  partial loss: 0.784419
# ---> iteration:  170  partial loss: 0.81139
# ---> iteration:  171  partial loss: 0.789067
# ---> iteration:  172  partial loss: 0.801958
# ---> iteration:  173  partial loss: 0.845662
# ---> iteration:  174  partial loss: 0.789732
# ---> iteration:  175  partial loss: 0.788149
# ---> iteration:  176  partial loss: 0.890218
# ---> iteration:  177  partial loss: 0.839177
# ---> iteration:  178  partial loss: 0.800867
# ---> iteration:  179  partial loss: 0.783455
# ---> iteration:  180  partial loss: 0.835011
# ---> iteration:  181  partial loss: 0.860898
# ---> iteration:  182  partial loss: 0.757278
# ---> iteration:  183  partial loss: 0.834714
# ---> iteration:  184  partial loss: 0.846742
# ---> iteration:  185  partial loss: 0.857723
# ---> iteration:  186  partial loss: 0.766131
# ---> iteration:  187  partial loss: 0.801582
# ---> iteration:  188  partial loss: 0.771712
# ---> iteration:  189  partial loss: 0.797872
# ---> iteration:  190  partial loss: 0.777258
# ---> iteration:  191  partial loss: 0.793399
# ---> iteration:  192  partial loss: 0.760482
# ---> iteration:  193  partial loss: 0.7705
# ---> iteration:  194  partial loss: 0.78417
# ---> iteration:  195  partial loss: 0.777516
# ---> iteration:  196  partial loss: 0.825905
# ---> iteration:  197  partial loss: 0.77676
# ---> iteration:  198  partial loss: 0.801273
# ---> iteration:  199  partial loss: 0.763609
# ---> iteration:  200  partial loss: 0.759365
# save model
# ---> iteration:  201  partial loss: 0.762331
# ---> iteration:  202  partial loss: 0.830664
# ---> iteration:  203  partial loss: 0.801151
# ---> iteration:  204  partial loss: 0.849383
# ---> iteration:  205  partial loss: 0.823629
# ---> iteration:  206  partial loss: 0.81193
# ---> iteration:  207  partial loss: 0.765636
# ---> iteration:  208  partial loss: 0.762027
# ---> iteration:  209  partial loss: 0.805382
# ---> iteration:  210  partial loss: 0.724161
# ---> iteration:  211  partial loss: 0.803895
# ---> iteration:  212  partial loss: 0.769448
# ---> iteration:  213  partial loss: 0.797445
# ---> iteration:  214  partial loss: 0.769883
# ---> iteration:  215  partial loss: 0.800485
# ---> iteration:  216  partial loss: 0.787495
# ---> iteration:  217  partial loss: 0.787864
# ---> iteration:  218  partial loss: 0.787824
# ---> iteration:  219  partial loss: 0.748963
# ---> iteration:  220  partial loss: 0.793706
# ---> iteration:  221  partial loss: 0.796906
# ---> iteration:  222  partial loss: 0.774712
# ---> iteration:  223  partial loss: 0.912881
# ---> iteration:  224  partial loss: 0.793711
# ---> iteration:  225  partial loss: 0.767388
# ---> iteration:  226  partial loss: 0.800554
# ---> iteration:  227  partial loss: 0.811649
# ---> iteration:  228  partial loss: 0.797029
# ---> iteration:  229  partial loss: 0.816144
# ---> iteration:  230  partial loss: 0.745609
# ---> iteration:  231  partial loss: 0.75073
# ---> iteration:  232  partial loss: 0.789246
# ---> iteration:  233  partial loss: 0.733034
# ---> iteration:  234  partial loss: 0.76897
# ---> iteration:  235  partial loss: 0.771265
# ---> iteration:  236  partial loss: 0.730416
# ---> iteration:  237  partial loss: 0.750827
# ---> iteration:  238  partial loss: 0.809992
# ---> iteration:  239  partial loss: 0.795137
# ---> iteration:  240  partial loss: 0.739736
# ---> iteration:  241  partial loss: 0.727205
# ---> iteration:  242  partial loss: 0.761381
# ---> iteration:  243  partial loss: 0.781146
# ---> iteration:  244  partial loss: 0.764808
# ---> iteration:  245  partial loss: 0.759012
# ---> iteration:  246  partial loss: 0.745223
# ---> iteration:  247  partial loss: 0.764206
# ---> iteration:  248  partial loss: 0.795057
# ---> iteration:  249  partial loss: 0.77287
# ---> iteration:  250  partial loss: 0.719827
# ---> iteration:  251  partial loss: 0.746893
# ---> iteration:  252  partial loss: 0.742775
# ---> iteration:  253  partial loss: 0.722161
# ---> iteration:  254  partial loss: 0.758631
# ---> iteration:  255  partial loss: 0.741432
# ---> iteration:  256  partial loss: 0.731837
# ---> iteration:  257  partial loss: 0.76764
# ---> iteration:  258  partial loss: 0.765955
# ---> iteration:  259  partial loss: 0.767132
# ---> iteration:  260  partial loss: 0.750599
# ---> iteration:  261  partial loss: 0.789861
# ---> iteration:  262  partial loss: 0.722816
# ---> iteration:  263  partial loss: 0.755729
# ---> iteration:  264  partial loss: 0.796979
# ---> iteration:  265  partial loss: 0.753645
# ---> iteration:  266  partial loss: 0.743766
# ---> iteration:  267  partial loss: 0.75683
# ---> iteration:  268  partial loss: 0.724759
# ---> iteration:  269  partial loss: 0.719958
# ---> iteration:  270  partial loss: 0.749694
# ---> iteration:  271  partial loss: 0.743933
# ---> iteration:  272  partial loss: 0.745874
# ---> iteration:  273  partial loss: 0.764694
# ---> iteration:  274  partial loss: 0.717261
# ---> iteration:  275  partial loss: 0.758185
# ---> iteration:  276  partial loss: 0.730351
# ---> iteration:  277  partial loss: 0.723588
# ---> iteration:  278  partial loss: 0.739925
# ---> iteration:  279  partial loss: 0.724549
# ---> iteration:  280  partial loss: 0.711914
# ---> iteration:  281  partial loss: 0.744009
# ---> iteration:  282  partial loss: 0.726078
# ---> iteration:  283  partial loss: 0.73391
# ---> iteration:  284  partial loss: 0.723416
# ---> iteration:  285  partial loss: 0.735371
# ---> iteration:  286  partial loss: 0.75876
# ---> iteration:  287  partial loss: 0.715677
# ---> iteration:  288  partial loss: 0.739651
# ---> iteration:  289  partial loss: 0.715273
# ------------------
# epoch:  1  of  20 training loss:  2.36934160856
# ------------------
# ---> iteration:  1  partial loss: 0.831474
# ---> iteration:  2  partial loss: 0.719791
# ---> iteration:  3  partial loss: 0.717129
# ---> iteration:  4  partial loss: 0.710102
# ---> iteration:  5  partial loss: 0.725957
# ---> iteration:  6  partial loss: 0.714062
# ---> iteration:  7  partial loss: 0.740392
# ---> iteration:  8  partial loss: 0.741876
# ---> iteration:  9  partial loss: 0.770527
# ---> iteration:  10  partial loss: 0.742147
# ---> iteration:  11  partial loss: 0.720069
# ---> iteration:  12  partial loss: 0.71667
# ---> iteration:  13  partial loss: 0.724405
# ---> iteration:  14  partial loss: 0.723894
# ---> iteration:  15  partial loss: 0.717823
# ---> iteration:  16  partial loss: 0.717379
# ---> iteration:  17  partial loss: 0.730898
# ---> iteration:  18  partial loss: 0.717984
# ---> iteration:  19  partial loss: 0.716464
# ---> iteration:  20  partial loss: 0.70577
# ---> iteration:  21  partial loss: 0.707806
# ---> iteration:  22  partial loss: 0.702754
# ---> iteration:  23  partial loss: 0.70677
# ---> iteration:  24  partial loss: 0.755713
# ---> iteration:  25  partial loss: 0.708431
# ---> iteration:  26  partial loss: 0.702047
# ---> iteration:  27  partial loss: 0.700048
# ---> iteration:  28  partial loss: 0.70839
# ---> iteration:  29  partial loss: 0.713835
# ---> iteration:  30  partial loss: 0.711396
# ---> iteration:  31  partial loss: 0.76532
# ---> iteration:  32  partial loss: 0.721001
# ---> iteration:  33  partial loss: 0.703169
# ---> iteration:  34  partial loss: 0.703622
# ---> iteration:  35  partial loss: 0.719724
# ---> iteration:  36  partial loss: 0.718791
# ---> iteration:  37  partial loss: 0.730904
# ---> iteration:  38  partial loss: 0.708529
# ---> iteration:  39  partial loss: 0.72354
# ---> iteration:  40  partial loss: 0.700097
# ---> iteration:  41  partial loss: 0.717454
# ---> iteration:  42  partial loss: 0.729613
# ---> iteration:  43  partial loss: 0.72282
# ---> iteration:  44  partial loss: 0.719183
# ---> iteration:  45  partial loss: 0.705886
# ---> iteration:  46  partial loss: 0.696425
# ---> iteration:  47  partial loss: 0.703243
# ---> iteration:  48  partial loss: 0.742521
# ---> iteration:  49  partial loss: 0.710641
# ---> iteration:  50  partial loss: 0.696103
# ---> iteration:  51  partial loss: 0.723615
# ---> iteration:  52  partial loss: 0.701741
# ---> iteration:  53  partial loss: 0.702977
# ---> iteration:  54  partial loss: 0.729443
# ---> iteration:  55  partial loss: 0.699168
# ---> iteration:  56  partial loss: 0.725323
# ---> iteration:  57  partial loss: 0.69904
# ---> iteration:  58  partial loss: 0.69867
# ---> iteration:  59  partial loss: 0.723299
# ---> iteration:  60  partial loss: 0.692291
# ---> iteration:  61  partial loss: 0.74735
# ---> iteration:  62  partial loss: 0.723621
# ---> iteration:  63  partial loss: 0.702971
# ---> iteration:  64  partial loss: 0.710043
# ---> iteration:  65  partial loss: 0.714701
# ---> iteration:  66  partial loss: 0.686726
# ---> iteration:  67  partial loss: 0.729821
# ---> iteration:  68  partial loss: 0.716781
# ---> iteration:  69  partial loss: 0.685518
# ---> iteration:  70  partial loss: 0.717858
# ---> iteration:  71  partial loss: 0.692948
# ---> iteration:  72  partial loss: 0.705766
# ---> iteration:  73  partial loss: 0.707192
# ---> iteration:  74  partial loss: 0.696617
# ---> iteration:  75  partial loss: 0.690218
# ---> iteration:  76  partial loss: 0.718621
# ---> iteration:  77  partial loss: 0.696459
# ---> iteration:  78  partial loss: 0.713846
# ---> iteration:  79  partial loss: 0.712776
# ---> iteration:  80  partial loss: 0.731581
# ---> iteration:  81  partial loss: 0.715092
# ---> iteration:  82  partial loss: 0.751214
# ---> iteration:  83  partial loss: 0.690302
# ---> iteration:  84  partial loss: 0.715718
# ---> iteration:  85  partial loss: 0.70488
# ---> iteration:  86  partial loss: 0.685266
# ---> iteration:  87  partial loss: 0.699363
# ---> iteration:  88  partial loss: 0.714265
# ---> iteration:  89  partial loss: 0.692893
# ---> iteration:  90  partial loss: 0.715448
# ---> iteration:  91  partial loss: 0.697002
# ---> iteration:  92  partial loss: 0.718848
# ---> iteration:  93  partial loss: 0.693011
# ---> iteration:  94  partial loss: 0.686147
# ---> iteration:  95  partial loss: 0.691264
# ---> iteration:  96  partial loss: 0.684449
# ---> iteration:  97  partial loss: 0.688465
# ---> iteration:  98  partial loss: 0.685996
# ---> iteration:  99  partial loss: 0.696309
# ---> iteration:  100  partial loss: 0.694084
# save model
# ---> iteration:  101  partial loss: 0.698784
# ---> iteration:  102  partial loss: 0.688651
# ---> iteration:  103  partial loss: 0.723634
# ---> iteration:  104  partial loss: 0.690164
# ---> iteration:  105  partial loss: 0.713871
# ---> iteration:  106  partial loss: 0.717194
# ---> iteration:  107  partial loss: 0.696105
# ---> iteration:  108  partial loss: 0.710208
# ---> iteration:  109  partial loss: 0.695983
# ---> iteration:  110  partial loss: 0.683024
# ---> iteration:  111  partial loss: 0.706176
# ---> iteration:  112  partial loss: 0.697289
# ---> iteration:  113  partial loss: 0.715011
# ---> iteration:  114  partial loss: 0.703779
# ---> iteration:  115  partial loss: 0.694456
# ---> iteration:  116  partial loss: 0.706079
# ---> iteration:  117  partial loss: 0.693475
# ---> iteration:  118  partial loss: 0.700645
# ---> iteration:  119  partial loss: 0.680365
# ---> iteration:  120  partial loss: 0.711211
# ---> iteration:  121  partial loss: 0.680416
# ---> iteration:  122  partial loss: 0.689543
# ---> iteration:  123  partial loss: 0.682227
# ---> iteration:  124  partial loss: 0.686397
# ---> iteration:  125  partial loss: 0.681701
# ---> iteration:  126  partial loss: 0.698629
# ---> iteration:  127  partial loss: 0.692264
# ---> iteration:  128  partial loss: 0.688137
# ---> iteration:  129  partial loss: 0.679199
# ---> iteration:  130  partial loss: 0.684959
# ---> iteration:  131  partial loss: 0.69113
# ---> iteration:  132  partial loss: 0.681945
# ---> iteration:  133  partial loss: 0.699778
# ---> iteration:  134  partial loss: 0.677689
# ---> iteration:  135  partial loss: 0.688587
# ---> iteration:  136  partial loss: 0.686183
# ---> iteration:  137  partial loss: 0.676099
# ---> iteration:  138  partial loss: 0.689137
# ---> iteration:  139  partial loss: 0.704974
# ---> iteration:  140  partial loss: 0.686202
# ---> iteration:  141  partial loss: 0.686147
# ---> iteration:  142  partial loss: 0.68095
# ---> iteration:  143  partial loss: 0.698096
# ---> iteration:  144  partial loss: 0.688545
# ---> iteration:  145  partial loss: 0.684246
# ---> iteration:  146  partial loss: 0.701115
# ---> iteration:  147  partial loss: 0.680062
# ---> iteration:  148  partial loss: 0.667409
# ---> iteration:  149  partial loss: 0.694031
# ---> iteration:  150  partial loss: 0.675559
# ---> iteration:  151  partial loss: 0.704776
# ---> iteration:  152  partial loss: 0.701938
# ---> iteration:  153  partial loss: 0.684529
# ---> iteration:  154  partial loss: 0.693768
# ---> iteration:  155  partial loss: 0.675804
# ---> iteration:  156  partial loss: 0.684535
# ---> iteration:  157  partial loss: 0.676175
# ---> iteration:  158  partial loss: 0.694213
# ---> iteration:  159  partial loss: 0.67795
# ---> iteration:  160  partial loss: 0.694881
# ---> iteration:  161  partial loss: 0.676356
# ---> iteration:  162  partial loss: 0.672226
# ---> iteration:  163  partial loss: 0.683184
# ---> iteration:  164  partial loss: 0.670492
# ---> iteration:  165  partial loss: 0.67819
# ---> iteration:  166  partial loss: 0.687565
# ---> iteration:  167  partial loss: 0.674516
# ---> iteration:  168  partial loss: 0.670883
# ---> iteration:  169  partial loss: 0.691994
# ---> iteration:  170  partial loss: 0.683278
# ---> iteration:  171  partial loss: 0.670489
# ---> iteration:  172  partial loss: 0.6733
# ---> iteration:  173  partial loss: 0.689747
# ---> iteration:  174  partial loss: 0.668929
# ---> iteration:  175  partial loss: 0.67592
# ---> iteration:  176  partial loss: 0.699404
# ---> iteration:  177  partial loss: 0.666081
# ---> iteration:  178  partial loss: 0.676637
# ---> iteration:  179  partial loss: 0.679565
# ---> iteration:  180  partial loss: 0.682894
# ---> iteration:  181  partial loss: 0.67966
# ---> iteration:  182  partial loss: 0.675872
# ---> iteration:  183  partial loss: 0.663499
# ---> iteration:  184  partial loss: 0.679106
# ---> iteration:  185  partial loss: 0.667341
# ---> iteration:  186  partial loss: 0.6696
# ---> iteration:  187  partial loss: 0.668458
# ---> iteration:  188  partial loss: 0.681886
# ---> iteration:  189  partial loss: 0.677355
# ---> iteration:  190  partial loss: 0.667853
# ---> iteration:  191  partial loss: 0.678291
# ---> iteration:  192  partial loss: 0.661415
# ---> iteration:  193  partial loss: 0.668056
# ---> iteration:  194  partial loss: 0.689378
# ---> iteration:  195  partial loss: 0.678028
# ---> iteration:  196  partial loss: 0.667741
# ---> iteration:  197  partial loss: 0.666845
# ---> iteration:  198  partial loss: 0.681456
# ---> iteration:  199  partial loss: 0.667248
# ---> iteration:  200  partial loss: 0.683101
# save model
# ---> iteration:  201  partial loss: 0.673755
# ---> iteration:  202  partial loss: 0.66947
# ---> iteration:  203  partial loss: 0.683704
# ---> iteration:  204  partial loss: 0.683509
# ---> iteration:  205  partial loss: 0.669488
# ---> iteration:  206  partial loss: 0.68586
# ---> iteration:  207  partial loss: 0.67849
# ---> iteration:  208  partial loss: 0.687816
# ---> iteration:  209  partial loss: 0.68345
# ---> iteration:  210  partial loss: 0.6767
# ---> iteration:  211  partial loss: 0.686671
# ---> iteration:  212  partial loss: 0.676184
# ---> iteration:  213  partial loss: 0.674439
# ---> iteration:  214  partial loss: 0.690748
# ---> iteration:  215  partial loss: 0.66093
# ---> iteration:  216  partial loss: 0.684436
# ---> iteration:  217  partial loss: 0.669718
# ---> iteration:  218  partial loss: 0.678161
# ---> iteration:  219  partial loss: 0.65755
# ---> iteration:  220  partial loss: 0.679847
# ---> iteration:  221  partial loss: 0.664632
# ---> iteration:  222  partial loss: 0.671065
# ---> iteration:  223  partial loss: 0.696361
# ---> iteration:  224  partial loss: 0.661218
# ---> iteration:  225  partial loss: 0.668458
# ---> iteration:  226  partial loss: 0.701305
# ---> iteration:  227  partial loss: 0.678541
# ---> iteration:  228  partial loss: 0.675303
# ---> iteration:  229  partial loss: 0.670408
# ---> iteration:  230  partial loss: 0.670074
# ---> iteration:  231  partial loss: 0.670131
# ---> iteration:  232  partial loss: 0.670007
# ---> iteration:  233  partial loss: 0.666537
# ---> iteration:  234  partial loss: 0.672678
# ---> iteration:  235  partial loss: 0.684443
# ---> iteration:  236  partial loss: 0.67147
# ---> iteration:  237  partial loss: 0.678122
# ---> iteration:  238  partial loss: 0.676165
# ---> iteration:  239  partial loss: 0.663675
# ---> iteration:  240  partial loss: 0.6834
# ---> iteration:  241  partial loss: 0.682101
# ---> iteration:  242  partial loss: 0.680886
# ---> iteration:  243  partial loss: 0.655504
# ---> iteration:  244  partial loss: 0.669926
# ---> iteration:  245  partial loss: 0.656212
# ---> iteration:  246  partial loss: 0.655725
# ---> iteration:  247  partial loss: 0.657368
# ---> iteration:  248  partial loss: 0.676934
# ---> iteration:  249  partial loss: 0.653506
# ---> iteration:  250  partial loss: 0.672906
# ---> iteration:  251  partial loss: 0.651511
# ---> iteration:  252  partial loss: 0.655955
# ---> iteration:  253  partial loss: 0.666841
# ---> iteration:  254  partial loss: 0.663641
# ---> iteration:  255  partial loss: 0.655891
# ---> iteration:  256  partial loss: 0.663897
# ---> iteration:  257  partial loss: 0.659695
# ---> iteration:  258  partial loss: 0.665788
# ---> iteration:  259  partial loss: 0.655884
# ---> iteration:  260  partial loss: 0.666299
# ---> iteration:  261  partial loss: 0.651419
# ---> iteration:  262  partial loss: 0.664141
# ---> iteration:  263  partial loss: 0.665632
# ---> iteration:  264  partial loss: 0.651054
# ---> iteration:  265  partial loss: 0.647662
# ---> iteration:  266  partial loss: 0.658511
# ---> iteration:  267  partial loss: 0.677244
# ---> iteration:  268  partial loss: 0.664671
# ---> iteration:  269  partial loss: 0.676381
# ---> iteration:  270  partial loss: 0.659813
# ---> iteration:  271  partial loss: 0.672021
# ---> iteration:  272  partial loss: 0.660095
# ---> iteration:  273  partial loss: 0.659273
# ---> iteration:  274  partial loss: 0.654726
# ---> iteration:  275  partial loss: 0.651947
# ---> iteration:  276  partial loss: 0.661847
# ---> iteration:  277  partial loss: 0.673189
# ---> iteration:  278  partial loss: 0.659665
# ---> iteration:  279  partial loss: 0.658468
# ---> iteration:  280  partial loss: 0.660392
# ---> iteration:  281  partial loss: 0.658426
# ---> iteration:  282  partial loss: 0.651898
# ---> iteration:  283  partial loss: 0.652897
# ---> iteration:  284  partial loss: 0.658273
# ---> iteration:  285  partial loss: 0.662535
# ---> iteration:  286  partial loss: 0.657891
# ---> iteration:  287  partial loss: 0.648144
# ---> iteration:  288  partial loss: 0.656296
# ---> iteration:  289  partial loss: 0.690737
# ------------------
# epoch:  2  of  20 training loss:  0.690014128866
# ------------------
# ---> iteration:  1  partial loss: 0.646049
# ---> iteration:  2  partial loss: 0.665802
# ---> iteration:  3  partial loss: 0.652156
# ---> iteration:  4  partial loss: 0.66078
# ---> iteration:  5  partial loss: 0.66092
# ---> iteration:  6  partial loss: 0.667089
# ---> iteration:  7  partial loss: 0.656775
# ---> iteration:  8  partial loss: 0.655852
# ---> iteration:  9  partial loss: 0.64601
# ---> iteration:  10  partial loss: 0.65812
# ---> iteration:  11  partial loss: 0.659694
# ---> iteration:  12  partial loss: 0.650402
# ---> iteration:  13  partial loss: 0.651824
# ---> iteration:  14  partial loss: 0.648299
# ---> iteration:  15  partial loss: 0.648787
# ---> iteration:  16  partial loss: 0.64759
# ---> iteration:  17  partial loss: 0.639245
# ---> iteration:  18  partial loss: 0.648282
# ---> iteration:  19  partial loss: 0.672172
# ---> iteration:  20  partial loss: 0.649932
# ---> iteration:  21  partial loss: 0.654895
# ---> iteration:  22  partial loss: 0.644526
# ---> iteration:  23  partial loss: 0.642397
# ---> iteration:  24  partial loss: 0.653518
# ---> iteration:  25  partial loss: 0.649041
# ---> iteration:  26  partial loss: 0.6478
# ---> iteration:  27  partial loss: 0.641827
# ---> iteration:  28  partial loss: 0.635447
# ---> iteration:  29  partial loss: 0.641224
# ---> iteration:  30  partial loss: 0.643419
# ---> iteration:  31  partial loss: 0.650144
# ---> iteration:  32  partial loss: 0.656187
# ---> iteration:  33  partial loss: 0.64738
# ---> iteration:  34  partial loss: 0.637568
# ---> iteration:  35  partial loss: 0.647116
# ---> iteration:  36  partial loss: 0.639693
# ---> iteration:  37  partial loss: 0.672013
# ---> iteration:  38  partial loss: 0.648839
# ---> iteration:  39  partial loss: 0.668406
# ---> iteration:  40  partial loss: 0.649413
# ---> iteration:  41  partial loss: 0.650271
# ---> iteration:  42  partial loss: 0.638818
# ---> iteration:  43  partial loss: 0.636549
# ---> iteration:  44  partial loss: 0.629175
# ---> iteration:  45  partial loss: 0.650296
# ---> iteration:  46  partial loss: 0.633612
# ---> iteration:  47  partial loss: 0.647315
# ---> iteration:  48  partial loss: 0.649913
# ---> iteration:  49  partial loss: 0.655651
# ---> iteration:  50  partial loss: 0.630453
# ---> iteration:  51  partial loss: 0.664882
# ---> iteration:  52  partial loss: 0.651402
# ---> iteration:  53  partial loss: 0.643656
# ---> iteration:  54  partial loss: 0.65523
# ---> iteration:  55  partial loss: 0.649536
# ---> iteration:  56  partial loss: 0.641261
# ---> iteration:  57  partial loss: 0.624207
# ---> iteration:  58  partial loss: 0.639479
# ---> iteration:  59  partial loss: 0.648289
# ---> iteration:  60  partial loss: 0.626069
# ---> iteration:  61  partial loss: 0.645397
# ---> iteration:  62  partial loss: 0.64823
# ---> iteration:  63  partial loss: 0.648332
# ---> iteration:  64  partial loss: 0.636419
# ---> iteration:  65  partial loss: 0.637517
# ---> iteration:  66  partial loss: 0.634473
# ---> iteration:  67  partial loss: 0.637309
# ---> iteration:  68  partial loss: 0.626038
# ---> iteration:  69  partial loss: 0.642589
# ---> iteration:  70  partial loss: 0.632236
# ---> iteration:  71  partial loss: 0.647333
# ---> iteration:  72  partial loss: 0.62243
# ---> iteration:  73  partial loss: 0.629134
# ---> iteration:  74  partial loss: 0.676915
# ---> iteration:  75  partial loss: 0.628448
# ---> iteration:  76  partial loss: 0.621604
# ---> iteration:  77  partial loss: 0.643692
# ---> iteration:  78  partial loss: 0.645104
# ---> iteration:  79  partial loss: 0.648423
# ---> iteration:  80  partial loss: 0.635363
# ---> iteration:  81  partial loss: 0.648858
# ---> iteration:  82  partial loss: 0.648628
# ---> iteration:  83  partial loss: 0.633614
# ---> iteration:  84  partial loss: 0.627824
# ---> iteration:  85  partial loss: 0.622492
# ---> iteration:  86  partial loss: 0.62635
# ---> iteration:  87  partial loss: 0.630299
# ---> iteration:  88  partial loss: 0.626431
# ---> iteration:  89  partial loss: 0.618693
# ---> iteration:  90  partial loss: 0.632263
# ---> iteration:  91  partial loss: 0.629872
# ---> iteration:  92  partial loss: 0.629369
# ---> iteration:  93  partial loss: 0.627348
# ---> iteration:  94  partial loss: 0.619511
# ---> iteration:  95  partial loss: 0.626609
# ---> iteration:  96  partial loss: 0.649008
# ---> iteration:  97  partial loss: 0.620043
# ---> iteration:  98  partial loss: 0.645335
# ---> iteration:  99  partial loss: 0.629757
# ---> iteration:  100  partial loss: 0.607078
# save model
# ---> iteration:  101  partial loss: 0.628494
# ---> iteration:  102  partial loss: 0.62668
# ---> iteration:  103  partial loss: 0.608665
# ---> iteration:  104  partial loss: 0.636021
# ---> iteration:  105  partial loss: 0.638333
# ---> iteration:  106  partial loss: 0.623874
# ---> iteration:  107  partial loss: 0.608439
# ---> iteration:  108  partial loss: 0.686462
# ---> iteration:  109  partial loss: 0.607063
# ---> iteration:  110  partial loss: 0.613681
# ---> iteration:  111  partial loss: 0.626132
# ---> iteration:  112  partial loss: 0.644697
# ---> iteration:  113  partial loss: 0.627483
# ---> iteration:  114  partial loss: 0.603814
# ---> iteration:  115  partial loss: 0.609552
# ---> iteration:  116  partial loss: 0.628209
# ---> iteration:  117  partial loss: 0.622042
# ---> iteration:  118  partial loss: 0.609998
# ---> iteration:  119  partial loss: 0.631863
# ---> iteration:  120  partial loss: 0.616409
# ---> iteration:  121  partial loss: 0.644758
# ---> iteration:  122  partial loss: 0.605447
# ---> iteration:  123  partial loss: 0.627678
# ---> iteration:  124  partial loss: 0.6538
# ---> iteration:  125  partial loss: 0.630259
# ---> iteration:  126  partial loss: 0.595109
# ---> iteration:  127  partial loss: 0.6254
# ---> iteration:  128  partial loss: 0.619796
# ---> iteration:  129  partial loss: 0.622325
# ---> iteration:  130  partial loss: 0.608205
# ---> iteration:  131  partial loss: 0.6166
# ---> iteration:  132  partial loss: 0.624455
# ---> iteration:  133  partial loss: 0.655323
# ---> iteration:  134  partial loss: 0.600974
# ---> iteration:  135  partial loss: 0.616539
# ---> iteration:  136  partial loss: 0.595803
# ---> iteration:  137  partial loss: 0.601498
# ---> iteration:  138  partial loss: 0.630214
# ---> iteration:  139  partial loss: 0.67121
# ---> iteration:  140  partial loss: 0.579672
# ---> iteration:  141  partial loss: 0.605836
# ---> iteration:  142  partial loss: 0.613229
# ---> iteration:  143  partial loss: 0.596786
# ---> iteration:  144  partial loss: 0.58368
# ---> iteration:  145  partial loss: 0.626339
# ---> iteration:  146  partial loss: 0.621516
# ---> iteration:  147  partial loss: 0.607442
# ---> iteration:  148  partial loss: 0.594472
# ---> iteration:  149  partial loss: 0.599819
# ---> iteration:  150  partial loss: 0.59694
# ---> iteration:  151  partial loss: 0.588289
# ---> iteration:  152  partial loss: 0.623475
# ---> iteration:  153  partial loss: 0.58304
# ---> iteration:  154  partial loss: 0.595101
# ---> iteration:  155  partial loss: 0.608721
# ---> iteration:  156  partial loss: 0.615504
# ---> iteration:  157  partial loss: 0.58716
# ---> iteration:  158  partial loss: 0.592604
# ---> iteration:  159  partial loss: 0.5868
# ---> iteration:  160  partial loss: 0.606755
# ---> iteration:  161  partial loss: 0.587999
# ---> iteration:  162  partial loss: 0.570514
# ---> iteration:  163  partial loss: 0.640126
# ---> iteration:  164  partial loss: 0.637238
# ---> iteration:  165  partial loss: 0.613505
# ---> iteration:  166  partial loss: 0.622721
# ---> iteration:  167  partial loss: 0.6173
# ---> iteration:  168  partial loss: 0.584614
# ---> iteration:  169  partial loss: 0.594458
# ---> iteration:  170  partial loss: 0.588205
# ---> iteration:  171  partial loss: 0.571066
# ---> iteration:  172  partial loss: 0.594279
# ---> iteration:  173  partial loss: 0.665665
# ---> iteration:  174  partial loss: 0.568268
# ---> iteration:  175  partial loss: 0.576366
# ---> iteration:  176  partial loss: 0.597111
# ---> iteration:  177  partial loss: 0.612994
# ---> iteration:  178  partial loss: 0.569157
# ---> iteration:  179  partial loss: 0.591951
# ---> iteration:  180  partial loss: 0.571528
# ---> iteration:  181  partial loss: 0.624774
# ---> iteration:  182  partial loss: 0.589405
# ---> iteration:  183  partial loss: 0.582525
# ---> iteration:  184  partial loss: 0.564346
# ---> iteration:  185  partial loss: 0.609548
# ---> iteration:  186  partial loss: 0.587814
# ---> iteration:  187  partial loss: 0.56737
# ---> iteration:  188  partial loss: 0.587129
# ---> iteration:  189  partial loss: 0.557349
# ---> iteration:  190  partial loss: 0.578455
# ---> iteration:  191  partial loss: 0.59469
# ---> iteration:  192  partial loss: 0.561193
# ---> iteration:  193  partial loss: 0.569491
# ---> iteration:  194  partial loss: 0.549517
# ---> iteration:  195  partial loss: 0.590897
# ---> iteration:  196  partial loss: 0.573543
# ---> iteration:  197  partial loss: 0.580968
# ---> iteration:  198  partial loss: 0.564615
# ---> iteration:  199  partial loss: 0.54169
# ---> iteration:  200  partial loss: 0.592979
# save model
# ---> iteration:  201  partial loss: 0.545744
# ---> iteration:  202  partial loss: 0.570937
# ---> iteration:  203  partial loss: 0.553947
# ---> iteration:  204  partial loss: 0.53793
# ---> iteration:  205  partial loss: 0.5545
# ---> iteration:  206  partial loss: 0.557345
# ---> iteration:  207  partial loss: 0.550031
# ---> iteration:  208  partial loss: 0.552543
# ---> iteration:  209  partial loss: 0.5651
# ---> iteration:  210  partial loss: 0.588456
# ---> iteration:  211  partial loss: 0.575691
# ---> iteration:  212  partial loss: 0.555041
# ---> iteration:  213  partial loss: 0.550975
# ---> iteration:  214  partial loss: 0.552889
# ---> iteration:  215  partial loss: 0.560231
# ---> iteration:  216  partial loss: 0.525338
# ---> iteration:  217  partial loss: 0.603201
# ---> iteration:  218  partial loss: 0.565859
# ---> iteration:  219  partial loss: 0.545715
# ---> iteration:  220  partial loss: 0.54974
# ---> iteration:  221  partial loss: 0.559718
# ---> iteration:  222  partial loss: 0.561328
# ---> iteration:  223  partial loss: 0.532981
# ---> iteration:  224  partial loss: 0.566809
# ---> iteration:  225  partial loss: 0.60011
# ---> iteration:  226  partial loss: 0.588804
# ---> iteration:  227  partial loss: 0.537553
# ---> iteration:  228  partial loss: 0.520898
# ---> iteration:  229  partial loss: 0.553061
# ---> iteration:  230  partial loss: 0.569723
# ---> iteration:  231  partial loss: 0.52574
# ---> iteration:  232  partial loss: 0.509996
# ---> iteration:  233  partial loss: 0.561944
# ---> iteration:  234  partial loss: 0.518529
# ---> iteration:  235  partial loss: 0.569692
# ---> iteration:  236  partial loss: 0.521159
# ---> iteration:  237  partial loss: 0.545796
# ---> iteration:  238  partial loss: 0.51822
# ---> iteration:  239  partial loss: 0.523779
# ---> iteration:  240  partial loss: 0.53298
# ---> iteration:  241  partial loss: 0.520982
# ---> iteration:  242  partial loss: 0.502395
# ---> iteration:  243  partial loss: 0.523012
# ---> iteration:  244  partial loss: 0.502151
# ---> iteration:  245  partial loss: 0.48876
# ---> iteration:  246  partial loss: 0.501842
# ---> iteration:  247  partial loss: 0.505667
# ---> iteration:  248  partial loss: 0.568145
# ---> iteration:  249  partial loss: 0.511403
# ---> iteration:  250  partial loss: 0.522632
# ---> iteration:  251  partial loss: 0.478864
# ---> iteration:  252  partial loss: 0.548582
# ---> iteration:  253  partial loss: 0.505374
# ---> iteration:  254  partial loss: 0.53167
# ---> iteration:  255  partial loss: 0.509343
# ---> iteration:  256  partial loss: 0.497688
# ---> iteration:  257  partial loss: 0.512402
# ---> iteration:  258  partial loss: 0.590033
# ---> iteration:  259  partial loss: 0.517191
# ---> iteration:  260  partial loss: 0.524646
# ---> iteration:  261  partial loss: 0.478606
# ---> iteration:  262  partial loss: 0.549289
# ---> iteration:  263  partial loss: 0.503838
# ---> iteration:  264  partial loss: 0.51265
# ---> iteration:  265  partial loss: 0.514133
# ---> iteration:  266  partial loss: 0.528649
# ---> iteration:  267  partial loss: 0.518953
# ---> iteration:  268  partial loss: 0.491919
# ---> iteration:  269  partial loss: 0.525743
# ---> iteration:  270  partial loss: 0.452084
# ---> iteration:  271  partial loss: 0.498808
# ---> iteration:  272  partial loss: 0.501521
# ---> iteration:  273  partial loss: 0.477491
# ---> iteration:  274  partial loss: 0.46659
# ---> iteration:  275  partial loss: 0.463187
# ---> iteration:  276  partial loss: 0.47579
# ---> iteration:  277  partial loss: 0.475389
# ---> iteration:  278  partial loss: 0.598945
# ---> iteration:  279  partial loss: 0.508673
# ---> iteration:  280  partial loss: 0.432407
# ---> iteration:  281  partial loss: 0.550717
# ---> iteration:  282  partial loss: 0.461232
# ---> iteration:  283  partial loss: 0.579335
# ---> iteration:  284  partial loss: 0.494073
# ---> iteration:  285  partial loss: 0.528248
# ---> iteration:  286  partial loss: 0.506476
# ---> iteration:  287  partial loss: 0.450584
# ---> iteration:  288  partial loss: 0.478655
# ---> iteration:  289  partial loss: 0.52265
# ------------------
# epoch:  3  of  20 training loss:  0.594458000058
# ------------------
# ---> iteration:  1  partial loss: 0.504821
# ---> iteration:  2  partial loss: 0.52015
# ---> iteration:  3  partial loss: 0.464076
# ---> iteration:  4  partial loss: 0.481508
# ---> iteration:  5  partial loss: 0.503206
# ---> iteration:  6  partial loss: 0.517083
# ---> iteration:  7  partial loss: 0.502519
# ---> iteration:  8  partial loss: 0.469418
# ---> iteration:  9  partial loss: 0.401546
# ---> iteration:  10  partial loss: 0.526948
# ---> iteration:  11  partial loss: 0.469228
# ---> iteration:  12  partial loss: 0.52002
# ---> iteration:  13  partial loss: 0.434602
# ---> iteration:  14  partial loss: 0.465858
# ---> iteration:  15  partial loss: 0.431422
# ---> iteration:  16  partial loss: 0.475688
# ---> iteration:  17  partial loss: 0.435333
# ---> iteration:  18  partial loss: 0.44165
# ---> iteration:  19  partial loss: 0.460075
# ---> iteration:  20  partial loss: 0.429419
# ---> iteration:  21  partial loss: 0.423818
# ---> iteration:  22  partial loss: 0.417221
# ---> iteration:  23  partial loss: 0.391676
# ---> iteration:  24  partial loss: 0.532714
# ---> iteration:  25  partial loss: 0.482877
# ---> iteration:  26  partial loss: 0.412264
# ---> iteration:  27  partial loss: 0.444799
# ---> iteration:  28  partial loss: 0.502598
# ---> iteration:  29  partial loss: 0.429851
# ---> iteration:  30  partial loss: 0.414123
# ---> iteration:  31  partial loss: 0.384026
# ---> iteration:  32  partial loss: 0.403028
# ---> iteration:  33  partial loss: 0.431244
# ---> iteration:  34  partial loss: 0.54065
# ---> iteration:  35  partial loss: 0.403818
# ---> iteration:  36  partial loss: 0.421439
# ---> iteration:  37  partial loss: 0.41799
# ---> iteration:  38  partial loss: 0.515357
# ---> iteration:  39  partial loss: 0.362757
# ---> iteration:  40  partial loss: 0.335741
# ---> iteration:  41  partial loss: 0.440562
# ---> iteration:  42  partial loss: 0.41903
# ---> iteration:  43  partial loss: 0.468559
# ---> iteration:  44  partial loss: 0.475478
# ---> iteration:  45  partial loss: 0.425484
# ---> iteration:  46  partial loss: 0.400969
# ---> iteration:  47  partial loss: 0.444543
# ---> iteration:  48  partial loss: 0.410348
# ---> iteration:  49  partial loss: 0.345294
# ---> iteration:  50  partial loss: 0.43265
# ---> iteration:  51  partial loss: 0.453171
# ---> iteration:  52  partial loss: 0.454995
# ---> iteration:  53  partial loss: 0.470295
# ---> iteration:  54  partial loss: 0.399048
# ---> iteration:  55  partial loss: 0.346096
# ---> iteration:  56  partial loss: 0.404109
# ---> iteration:  57  partial loss: 0.376692
# ---> iteration:  58  partial loss: 0.35736
# ---> iteration:  59  partial loss: 0.36233
# ---> iteration:  60  partial loss: 0.398449
# ---> iteration:  61  partial loss: 0.355168
# ---> iteration:  62  partial loss: 0.374278
# ---> iteration:  63  partial loss: 0.454092
# ---> iteration:  64  partial loss: 0.364893
# ---> iteration:  65  partial loss: 0.426732
# ---> iteration:  66  partial loss: 0.40361
# ---> iteration:  67  partial loss: 0.390636
# ---> iteration:  68  partial loss: 0.390776
# ---> iteration:  69  partial loss: 0.416985
# ---> iteration:  70  partial loss: 0.359059
# ---> iteration:  71  partial loss: 0.358742
# ---> iteration:  72  partial loss: 0.369147
# ---> iteration:  73  partial loss: 0.351173
# ---> iteration:  74  partial loss: 0.396638
# ---> iteration:  75  partial loss: 0.365842
# ---> iteration:  76  partial loss: 0.382538
# ---> iteration:  77  partial loss: 0.454084
# ---> iteration:  78  partial loss: 0.376106
# ---> iteration:  79  partial loss: 0.324208
# ---> iteration:  80  partial loss: 0.345125
# ---> iteration:  81  partial loss: 0.26966
# ---> iteration:  82  partial loss: 0.308433
# ---> iteration:  83  partial loss: 0.285217
# ---> iteration:  84  partial loss: 0.428226
# ---> iteration:  85  partial loss: 0.298189
# ---> iteration:  86  partial loss: 0.350018
# ---> iteration:  87  partial loss: 0.354578
# ---> iteration:  88  partial loss: 0.246833
# ---> iteration:  89  partial loss: 0.346485
# ---> iteration:  90  partial loss: 0.358869
# ---> iteration:  91  partial loss: 0.364514
# ---> iteration:  92  partial loss: 0.299703
# ---> iteration:  93  partial loss: 0.349276
# ---> iteration:  94  partial loss: 0.330231
# ---> iteration:  95  partial loss: 0.333075
# ---> iteration:  96  partial loss: 0.280895
# ---> iteration:  97  partial loss: 0.322873
# ---> iteration:  98  partial loss: 0.274552
# ---> iteration:  99  partial loss: 0.308694
# ---> iteration:  100  partial loss: 0.303531
# save model

# %%
all_training_losses
